# %% [markdown]
# ### 반복문-문제11

# %%
num = input("input an integer: ")
for i in num:
    print("★"*int(i))
# Out:
# input an integer: 3159
# ★★★
# ★
# ★★★★★
# ★★★★★★★★★

# %%
num = input("input an integer: ")
for i in num:
    for y in range(int(i)):
        print("★", end = "")
    print()
# Out:
# input an integer: 3159
# ★★★
# ★
# ★★★★★
# ★★★★★★★★★

# %% [markdown]
# ### 반복문-문제12

# %%
nums = []
while True:
    num = input("Enter a number: ")
    if num != 'done':
        nums.append(float(num))
    else:
        break

print()
print(nums)
print('Average: %.1f'%(sum(nums)/len(nums)))
print('Maximum: %.1f'%max(nums))
print('Minimum: %.1f'%min(nums))
# Out:
# Enter a number: 7
# Enter a number: 2
# Enter a number: 9
# Enter a number: 3
# Enter a number: 5
# Enter a number: done
#
# [7.0, 2.0, 9.0, 3.0, 5.0]
# Average: 5.2
# Maximum: 9.0
# Minimum: 2.0

# %%
nums = []
while True:
    num = input("Enter a number: ")
    if num == 'done':
        break
    nums.append(float(num))

print()
print(nums)
print('Average: %.1f'%(sum(nums)/len(nums)))
print('Maximum: %.1f'%max(nums))
print('Minimum: %.1f'%min(nums))
# Out:
# Enter a number: 7
# Enter a number: 2
# Enter a number: 9
# Enter a number: 3
# Enter a number: 5
# Enter a number: done
#
# [7.0, 2.0, 9.0, 3.0, 5.0]
# Average: 5.2
# Maximum: 9.0
# Minimum: 2.0

# %% [markdown]
# ### 딕셔너리- 실습1

# %%
d ={'youn':1,'park':2,'kim':10}

for value in d.values():
    print(value, end=' ')
# Out:
# 1 2 10

# %%
for key in d.keys():
    print(d[key], end = ' ')
# Out:
# 1 2 10

# %%
for item in d.items():
    key, value = item
    print(value, end = ' ')
# Out:
# 1 2 10

# %% [markdown]
# ### 딕셔너리- 실습2

# %%
a = {'one':1,'two':2,'three':3,'four':4,'five':5}
for key, value in sorted(a.items()):
        print(key, value)
# Out:
# five 5
# four 4
# one 1
# three 3
# two 2

# %% [markdown]
# ### 딕셔너리- 실습3

# %%
dic = {}
sen = input("Enter a sentence: ")
sen_set = set(sen)

for i in sen_set:
    dic[i] = sen.count(i)
print(dic, end = '')
# Out:
# Enter a sentence: Python is fun!
# {'o': 1, 'f': 1, 'P': 1, 'i': 1, 'h': 1, 's': 1, 'y': 1, ' ': 2, 'n': 2, 'u': 1, 't': 1, '!': 1}

# %%
dic = {}
sen = input("Enter a sentence: ")

for i in sen:
    if i in dic:
        dic[i] += 1
    else:
        dic[i] = 1
print(dic, end = '')
# Out:
# Enter a sentence: Python is fun!
# {'P': 1, 'y': 1, 't': 1, 'h': 1, 'o': 1, 'n': 2, ' ': 2, 'i': 1, 's': 1, 'f': 1, 'u': 1, '!': 1}

# %% [markdown]
# ### 파일- 실습3

# %%
fr = open('test.txt','r')
data = fr.read()
fr.close()

info = {}
data.split()
for i in data.split():
    if i in info:
        info[i] += 1
    else:
        info[i] = 1

for key, value in (info.items()):
        print(key, value)
# Out:
# first 1
# line 3
# second 1
# third 1

# %% [markdown]
# ### 파일 - 실습4

# %%
f = open('score.txt','r')
lines = f.read()
f.close()
lines = lines.split('\n')

fw = open('report.txt','w')

for i in range(len(lines)):
    mid = int(lines[i][7:9])
    final = int(lines[i][10:12])
    total = (mid*0.4) + (final*0.6)

    if total >= 90:
        fw.write(f'{lines[i]}  {total}(A)\n')
    elif total >= 80:
        fw.write(f'{lines[i]}  {total}(B)\n')
    elif total >= 70:
        fw.write(f'{lines[i]}  {total}(C)\n')
    elif total >= 60:
        fw.write(f'{lines[i]}  {total}(D)\n')
    else:
        fw.write(f'{lines[i]}  {total}(F)\n')

fw.close()
