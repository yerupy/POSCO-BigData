# %%
def avg_1(중간, 기말):
    중간, 기말 성적으로 avg와 grade 구하기
    return avg와 grade

def print_:
    column명과 ----------- 출력
    
def show:
    학생 리스트를 평균값 기준 내림차순으로 정렬후 한 줄 씩 출력
    
def search(n,a,리스트):
    if 리스트[n] 값이 input으로 받은 a와 같으면:
            return 해당 리스트 요소
    if input으로 받은 값이 리스트 내에 존재하지 않으면:
        return None

def changescore(c,n):
    if c가 100보다 크거나 or 0보다 작으면:
        pass
    else:            
        if stu_list1[0]이 input으로 받은 stu_id와 같으면:
            리스트 해당 인덱스(n)에 변경할 점수(c) 저장, avg_1 함수로 avg와 grade 반환 후 list에 각각 저장
            해당 stu_id가 포함된 이전 stu_list 요소, Score changes, 수정된 stu_list1 요소 한줄로 출력

입력된 파일 읽기
    students.txt 파일 읽고 변수 data 에 파일 내용 저장
파일 닫기

불러온 data 한 줄 씩 split
stu_list = []

for data 반복:
    탭을 기준으로 split 한 data 요소들 stu_list에 추가

for stu_list 반복:
    avg_1 함수로 avg, grade 반환 후 이중리스트 안 리스트에 avg,grade를 추가
    
while 값이 있을동안:
    변수 a에 input
    input되는 값 모두 소문자로 변환
    
    if a가 'show'일때:
        함수 show
        
    if a가 'search'일때:
        if search 함수 return된 값 있을 시:
            print_함수와 해당 값이 존재하는 리스트 요소 출력
        else:
            NO SUCH PERSON 오류 메세지 출력
            
    if a가 'changescore'일때:
        stu_list을 stu_list1에 deepcopy
        if search 함수 return 없으면:
            NO SUCH PERSON 오류 메세지 출력
        for 리스트 반복:
            mid인지 final인지 물어보는 input 추가
            if mid이면:
                 changescore 통해 값 변경
            elif final이면:
                 changescore 통해 값 변경
        stu_list에 stu_list1 대입
    
    if a가 'add'일때:
        if search 함수 return 있으면:
            ALREADY EXISTS 오류 메세지 출력
        else:
            name, mid, final 값 대입후 stu_list 값 변경

    if a가 'searchgrade'일때:
        if search 함수 return 있으면:
            해당 리스트 요소 출력
        else:
            NO RESULTS 오류 메세지 출력
    
    if a가 'remove'일때:
        if 리스트 비어있으면:
            LIST IS EMPTY 오류 메세지 출력
        else:
            if search 함수 return 있으면:
                stu_id가 포함된 리스트 삭제
            else:
                NO SUCH PERSON 오류 메세지 출력
                
    if a가 'quit'일때:
        데이터 저장 여부 묻기
        yes시 stu_list 정렬 및 문자열로 저장, 
        파일쓰기
        break
