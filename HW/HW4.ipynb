# %% [markdown]
# ### 실습2

# %%
import os

file_name = input("Enter a file name: ")

if os.path.exists(file_name):
    with open(file_name,'r') as f:
        for line in f:
            print(line.upper(), end='')
else:
    print('파일이 존재하지 않는다')
# Out:
# Enter a file name: tst.txt
# 파일이 존재하지 않는다

# %% [markdown]
# ### 실습3

# %% [markdown]
# ![Screenshot%20from%202020-11-05%2020-41-18.png](attachment:Screenshot%20from%202020-11-05%2020-41-18.png)
