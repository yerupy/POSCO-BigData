# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

#분류 Dicision Tree
from sklearn.tree import DecisionTreeClassifier
#데이터 분할
from sklearn.model_selection import train_test_split
#confusion matrix
from sklearn.metrics import confusion_matrix

import graphviz
from sklearn.tree import export_graphviz
from sklearn.model_selection import GridSearchCV

#분류 random forest
from sklearn.ensemble import RandomForestClassifier as RFC

# %%
matplotlib.rc('font', family = 'NanumGothic')

# %% [markdown]
# ## 1. 의사결정나무

# %% [markdown]
# ### 데이터 구성하기

# %%
df_raw = pd.read_csv('/home/piai/Downloads/유방암.csv', engine = 'python')
df_raw.head()
# Out:
#    diagnosis  mean radius  mean texture  mean perimeter  mean area  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    mean smoothness  mean compactness  mean concavity  mean concave points  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    mean symmetry  ...  worst radius  worst texture  worst perimeter  \
# ...

# %%
#결측치 확인하기
df_raw.isnull().sum(axis = 0)
# Out:
# diagnosis                  0
# mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# dtype: int64

# %%
#설명변수 데이터 type 확인
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    int64
#  1   mean radius              569 non-null    float64
#  2   mean texture             569 non-null    float64
#  3   mean perimeter           569 non-null    float64
#  4   mean area                569 non-null    float64
#  5   mean smoothness          569 non-null    float64
#  6   mean compactness         569 non-null    float64
#  7   mean concavity           569 non-null    float64
#  8   mean concave points      569 non-null    float64
#  9   mean symmetry            569 non-null    float64
#  10  mean fractal dimension   569 non-null    float64
#  11  radius error             569 non-null    float64
#  12  texture error            569 non-null    float64
# ...

# %% [markdown]
#  * 범주형 데이터 있을 시 더미 변수 생성 BUT 해당 데이터에는 범주형 데이터 존재하지 않음

# %% [markdown]
# ### 데이터 분할

# %%
#목표변수, 설명변수 데이터 지정
df_raw_y = df_raw['diagnosis']
df_raw_x = df_raw.drop('diagnosis', axis = 1 , inplace = False)

# %%
#train_test_split (X : 설명변수 데이터, Y : 목표변수 데이터, test_size = test 데이터 비율, random_state : random seed)

df_train_x, df_test_x, df_train_y, df_test_y = train_test_split(df_raw_x, df_raw_y,test_size = 0.3, random_state = 1234)
df_train_x, df_val_x, df_train_y , df_val_y = train_test_split(df_train_x, df_train_y, test_size = 3/7, random_state = 1234)
print(f'train data X size :{df_train_x.shape}')
print(f'train data Y size :{df_train_y.shape}')
print(f'test data X size :{df_test_x.shape}')
print(f'test data Y size :{df_test_y.shape}')
print(f'val data X size :{df_val_x.shape}')
print(f'val data Y size :{df_val_y.shape}')
# Out:
# train data X size :(227, 30)
# train data Y size :(227,)
# test data X size :(171, 30)
# test data Y size :(171,)
# val data X size :(171, 30)
# val data Y size :(171,)

# %% [markdown]
# ### 모델 생성

# %%
#모델 생성
tree_uncustomized = DecisionTreeClassifier(random_state = 1234)
tree_uncustomized.fit(df_train_x, df_train_y)

#train 데이터 설명력
print('Accuracy on training set : {:.3f}'.format(tree_uncustomized.score(df_train_x, df_train_y)))

#test 데이터 설명력
print('Accuracy on val set : {:.3f}'.format(tree_uncustomized.score(df_val_x, df_val_y)))
# Out:
# Accuracy on training set : 1.000
# Accuracy on val set : 0.936

# %%
tree_uncustomized
# Out:
# DecisionTreeClassifier(random_state=1234)

# %% [markdown]
# ### 모델 parameter 조정
# ### max_depth: 최대 깊이 변경에 따른 모델 성능

# %%
#max_depth: 최대 깊이 변경에 따른 모델 성능
#train 및 val 설명력 결과 저장
train_accuracy = []
val_accuracy = []

para_depth = [depth for depth in range(1,11)]

for v_max_depth in para_depth:
    tree = DecisionTreeClassifier(random_state = 1234,
                                 max_depth = v_max_depth)
    tree.fit(df_train_x, df_train_y)
    train_accuracy.append(tree.score(df_train_x, df_train_y))
    val_accuracy.append(tree.score(df_val_x, df_val_y))

#결과 저장
df_accuracy_depth = pd.DataFrame()
df_accuracy_depth['Depth'] = para_depth
df_accuracy_depth['TrainScore'] = train_accuracy
df_accuracy_depth['ValScore'] = val_accuracy
df_accuracy_depth.round(3)
# Out:
#    Depth  TrainScore  ValScore
# 0      1       0.943     0.912
# 1      2       0.982     0.942
# 2      3       0.982     0.942
# 3      4       0.996     0.936
# 4      5       1.000     0.936
# 5      6       1.000     0.936
# 6      7       1.000     0.936
# 7      8       1.000     0.936
# 8      9       1.000     0.936
# 9     10       1.000     0.936

# %%
#모델 설명력 그래프 확인
plt.plot(para_depth, train_accuracy, linestyle = "-", label = 'Train Accuracy')
plt.plot(para_depth, val_accuracy, linestyle = "--", label = 'Val Accuracy')
plt.legend()

# %% [markdown]
# * 깊이 2 이후에는 모델의 정확도가 일정한 것으로 보아 정확도가 높은 6 선택

# %%
#변수명 저장
v_feature_name = df_train_x.columns

#최대 깊이 = 4 모델
tree_low = DecisionTreeClassifier(max_depth = 6,random_state = 1234)
tree_low.fit(df_train_x , df_train_y)

#트리 모델을 tree_low.dot 파일로 저장(목표변수 , 0: Malignant, 1:Benign)
export_graphviz(tree_low, out_file = 'tree_low.dot', class_names = ['Malignant', 'Benign'], 
                feature_names = v_feature_name, impurity = True, filled = True)
with open('tree_low.dot') as f:
    dot_graph = f.read()
display(graphviz.Source(dot_graph))

# %% [markdown]
# ### min_samples_split : 분리 노드의 최소 자료 수 변경에 따른 모델 성능

# %%
#train 및 val 설명력 결과 저장
train_accuracy = []
val_accuracy = []

#min_samples_split : 분리노드 최소 자료 수 * 참조 : para_split : [1,2,3,...,19]

para_split = [n_split * 10 for n_split in range(1,11)]

for v_min_samples_split in para_split:
    tree = DecisionTreeClassifier(random_state = 1234,
                                 max_depth = 6,
                                 min_samples_split = v_min_samples_split)
    tree.fit(df_train_x, df_train_y)
    train_accuracy.append(tree.score(df_train_x, df_train_y))
    val_accuracy.append(tree.score(df_val_x, df_val_y))

#결과 저장
df_score_split = pd.DataFrame()
df_score_split['MinSamplesSplit'] = para_split
df_score_split['Trainaccuracy'] = train_accuracy
df_score_split['Valaccuracy'] = val_accuracy
df_score_split.round(3)
# Out:
#    MinSamplesSplit  Trainaccuracy  Valaccuracy
# 0               10          0.996        0.936
# 1               20          0.982        0.942
# 2               30          0.982        0.942
# 3               40          0.982        0.942
# 4               50          0.982        0.942
# 5               60          0.982        0.942
# 6               70          0.982        0.942
# 7               80          0.974        0.936
# 8               90          0.974        0.936
# 9              100          0.974        0.936

# %%
#모델 설명력 그래프 확인
plt.plot(para_split, train_accuracy, linestyle = "-", label = 'Trainaccuracy')
plt.plot(para_split, val_accuracy, linestyle = "--", label = 'Valaccuracy')
plt.legend()

# %% [markdown]
# * 분리 노드의 최소 자료 수 증가에 따라 모델의 정확도는 감소한다.
# * 따라서 val 데이터의 성능 변화를 고려하여 val 데이터 정확도가 가장 높은 20 선택

# %%
#변수명 저장
v_feature_name = df_train_x.columns

#분리 노드의 최소 자료 수 = 20 모델
tree_low = DecisionTreeClassifier(max_depth = 6,
                                  min_samples_split = 20,
                                  random_state = 1234)
tree_low.fit(df_train_x , df_train_y)
    
export_graphviz(tree_low, out_file = 'tree_low.dot', class_names = ['Malignant', 'Benign'],
                feature_names = v_feature_name, impurity = True, filled = True)
with open('tree_low.dot') as f:
    dot_graph = f.read()
display(graphviz.Source(dot_graph))

# %% [markdown]
# ### min_samples_leaf : 잎사귀 노드의 최소 자료 수 변경에 따른 모델 성능

# %%
#train 및 val 설명력 결과 저장
train_accuracy = []
val_accuracy = []

#min_samples_leaf : 잎사귀 최소 자료 수 * 참조 : para_leaf : [1,2,3,...,19]

para_leaf = [n_leaf * 2 for n_leaf in range(1,11)]
for v_min_samples_leaf in para_leaf:
    tree = DecisionTreeClassifier(random_state = 1234 , min_samples_leaf = v_min_samples_leaf,
                                  max_depth = 6,
                                  min_samples_split = 20)
    tree.fit(df_train_x, df_train_y)
    train_accuracy.append(tree.score(df_train_x, df_train_y))
    val_accuracy.append(tree.score(df_val_x, df_val_y))
    
#결과 저장
df_score_leaf = pd.DataFrame()
df_score_leaf['MinSamplesLeaf'] = para_leaf
df_score_leaf['TrainAccuracy'] = train_accuracy
df_score_leaf['valAccuracy'] = val_accuracy
#모델 설명력 확인
df_score_leaf.round(3)
# Out:
#    MinSamplesLeaf  TrainAccuracy  valAccuracy
# 0               2          0.982        0.942
# 1               4          0.974        0.942
# 2               6          0.974        0.936
# 3               8          0.969        0.930
# 4              10          0.969        0.930
# 5              12          0.960        0.936
# 6              14          0.952        0.924
# 7              16          0.943        0.912
# 8              18          0.943        0.912
# 9              20          0.943        0.912

# %%
#모델 설명력 그래프 확인
plt.plot(para_leaf, train_accuracy, linestyle = "-", label = 'Train accuracy')
plt.plot(para_leaf, test_accuracy, linestyle = "--", label = 'Val accuracy')
plt.legend()

# %% [markdown]
# * 잎사귀 노드 최소 자료 수 증가에 따라 모델의 정확도는 감소. 따라서 val 정확도와 train 정확도를 모두 고려하여 10 선정

# %%
#변수명 저장
v_feature_name = df_train_x.columns

#노드의 최소 자료 수 = 8 모델
tree_low = DecisionTreeClassifier(random_state = 1234, min_samples_leaf = 10,max_depth = 6,
                                  min_samples_split = 20)
tree_low.fit(df_train_x , df_train_y)
export_graphviz(tree_low, out_file = 'tree_low.dot', class_names = ['Malignant','Benign'],
                feature_names = v_feature_name, impurity = True, filled = True)
with open('tree_low.dot') as f:
    dot_graph = f.read()
display(graphviz.Source(dot_graph))

# %% [markdown]
# ### 최종 모델 선정

# %%
#모델 생성
tree_final = DecisionTreeClassifier(min_samples_leaf = 10, min_samples_split = 20, max_depth = 6, random_state = 1234)
tree_final.fit(df_train_x, df_train_y)

#train 데이터 설명력
print('Score on training set : {:.3f}'.format(tree_final.score(df_train_x, df_train_y)))

#test 데이터 설명력
print('Score on test set : {:.3f}'.format(tree_final.score(df_test_x, df_test_y)))
# Out:
# Score on training set : 0.969
# Score on test set : 0.930

# %% [markdown]
# * test 데이터의 설명력이 93.0% 인 것을 알 수 있다

# %% [markdown]
# ### 최종 모델 시각화

# %%
tree_final = DecisionTreeClassifier(min_samples_leaf = 10, min_samples_split = 20, max_depth = 6, random_state = 1234)
tree_final.fit(df_train_x, df_train_y)

export_graphviz(tree_final, out_file = 'tree_final.dot', class_names = ['Malignant','Benign'],
                feature_names = v_feature_name, impurity = True, filled = True)
with open('tree_final.dot') as f:
    dot_graph = f.read()
display(graphviz.Source(dot_graph))

# %% [markdown]
# ### 최종 모델 평가

# %%
y_pred = tree_final.predict(df_test_x)
print('Accuracy: {0:3f}\n'.format(tree_final.score(df_test_x, df_test_y)))
print('Confusion matrix : \n{}'.format(confusion_matrix(df_test_y, y_pred)))
# Out:
# Accuracy: 0.929825
#
# Confusion matrix :
# [[98  7]
#  [ 5 61]]

# %% [markdown]
# * confusion matrix 를 통해 확인해본 결과 이 모델은 안정적인 모델임을 확인할 수 있다

# %% [markdown]
# ### 결론 도출
# ### feature_importances_ : 설명변수의 중요도

# %%
#나무를 만들 때 사용되는 변수들의 중요도
#feature_importances_ : 설명변수의 중요도
#tree_final, feature_importances_로 설명변수 중요도 확인 및 테이블로 저장
df_importance = pd.DataFrame()
df_importance['Feature'] = v_feature_name
df_importance['Importance'] = tree_final.feature_importances_

#df_feature_importance 의 테이블을 중요도별로 정렬
df_importance.sort_values('Importance', ascending = False, inplace = True)
df_importance.round(3)
# Out:
#                     Feature  Importance
# 27     worst concave points       0.912
# 13               area error       0.078
# 1              mean texture       0.005
# 22          worst perimeter       0.004
# 0               mean radius       0.000
# 16          concavity error       0.000
# 28           worst symmetry       0.000
# 26          worst concavity       0.000
# 25        worst compactness       0.000
# 24         worst smoothness       0.000
# 23               worst area       0.000
# 21            worst texture       0.000
# 20             worst radius       0.000
# 19  fractal dimension error       0.000
# 18           symmetry error       0.000
# 17     concave points error       0.000
# 15        compactness error       0.000
# 14         smoothness error       0.000
# 12          perimeter error       0.000
# 11            texture error       0.000
# 10             radius error       0.000
# 9    mean fractal dimension       0.000
# ...

# %%
#설명변수 중요도 그래프, 중요도가 높은 변수를 상위에 그림
df_importance.sort_values('Importance', ascending = True, inplace = True)
coordinates = range(len(df_importance))
plt.barh(y = coordinates, width = df_importance['Importance'])
plt.yticks(coordinates, df_importance['Feature'])
plt.xlabel('변수 중요도')
plt.ylabel('변수')
# Out:
# Text(0, 0.5, '변수')

# %% [markdown]
# * 중요 설명 변수 : 트리 생성 시 worst concave points , area error 순으로 유방암에 대한 영향도가 큰 것을 알 수 있음.
# * 즉 유방암 악성을 구분하는데에 있어 worst concave points , area error 변수가 큰 영향을 미치는 것을 알 수 있다.

# %% [markdown]
# ### GridSearchCV 를 이용한 최적 parameter 찾기

# %%
estimator = DecisionTreeClassifier()

#구하고자 하는 parameter 와 범위
param_grid = {'max_depth' : para_depth, 'min_samples_split' : para_split, 'min_samples_leaf': para_leaf}

#정확도가 높은 최적 parameter 찾기
grid_dt = GridSearchCV(estimator, param_grid, scoring = 'accuracy', n_jobs =-1)
grid_dt.fit(df_train_x, df_train_y)

print(f'best estimator model : \n {grid_dt.best_estimator_}')
print(f'\nbest parameter : \n {grid_dt.best_params_}')
print(f'\nbest score : \n {grid_dt.best_score_.round(3)}')
# Out:
# best estimator model :
#  DecisionTreeClassifier(max_depth=8, min_samples_leaf=2, min_samples_split=30)
#
# best parameter :
#  {'max_depth': 8, 'min_samples_leaf': 2, 'min_samples_split': 30}
#
# best score :
#  0.956

# %% [markdown]
# * GridSearchCV를 이용한 최적 parameter 를 찾은 결과 최대 depth는 8, 최소 잎사귀 노드 수는 2, 최소 분리노드수는 30 인 것을 알 수 있다

# %% [markdown]
# ## 2. 랜덤 포레스트

# %% [markdown]
# ### 데이터 구성

# %%
df_raw = pd.read_csv('/home/piai/Downloads/유방암.csv', engine = 'python')
df_raw.head()

# %% [markdown]
# ### 데이터 분할

# %%
#목표변수, 설명변수 데이터 지정
df_raw_y = df_raw['diagnosis']
df_raw_x = df_raw.drop('diagnosis', axis = 1 , inplace = False)

# %%
#train_test_split (X : 설명변수 데이터, Y : 목표변수 데이터, test_size = test 데이터 비율, random_state : random seed)

df_train_x, df_test_x, df_train_y, df_test_y = train_test_split(df_raw_x, df_raw_y,test_size = 0.3, random_state = 1234)
df_train_x, df_val_x, df_train_y , df_val_y = train_test_split(df_train_x, df_train_y, test_size = 3/7, random_state = 1234)
print(f'train data X size :{df_train_x.shape}')
print(f'train data Y size :{df_train_y.shape}')
print(f'test data X size :{df_test_x.shape}')
print(f'test data Y size :{df_test_y.shape}')
print(f'val data X size :{df_val_x.shape}')
print(f'val data Y size :{df_val_y.shape}')
# Out:
# train data X size :(227, 30)
# train data Y size :(227,)
# test data X size :(171, 30)
# test data Y size :(171,)
# val data X size :(171, 30)
# val data Y size :(171,)

# %% [markdown]
# ### 모델 생성

# %%
#모델 생성
tree_uncustomized = RFC(random_state = 1234)
tree_uncustomized.fit(df_train_x, df_train_y)

#train 데이터 설명력
print('Accuracy on training set : {:.3f}'.format(tree_uncustomized.score(df_train_x, df_train_y)))

#test 데이터 설명력
print('Accuracy on val set : {:.3f}'.format(tree_uncustomized.score(df_val_x, df_val_y)))
# Out:
# Accuracy on training set : 1.000
# Accuracy on val set : 0.953

# %% [markdown]
# ### n_estimators: 트리 수 변경에 따른 모델 성능

# %%
#train 및 val 설명력 결과 저장
train_accuracy = []
val_accuracy = []

### n_estimators: 트리 수 변경 1~100

para_n_tree = [n_tree * 10 for n_tree in range(1,16)]
for v_n_estimators in para_n_tree:
    rf = RFC(random_state = 1234 , 
             n_estimators = v_n_estimators)
    rf.fit(df_train_x, df_train_y)
    train_accuracy.append(rf.score(df_train_x, df_train_y))
    val_accuracy.append(rf.score(df_val_x, df_val_y))
    
#결과 저장
df_score_n = pd.DataFrame()
df_score_n['n_estimators'] = para_n_tree
df_score_n['Trainaccuracy'] = train_accuracy
df_score_n['valaccuracy'] = val_accuracy
df_score_n.round(3)
# Out:
#     n_estimators  Trainaccuracy  valaccuracy
# 0             10          0.996        0.953
# 1             20          0.996        0.953
# 2             30          1.000        0.953
# 3             40          1.000        0.953
# 4             50          1.000        0.947
# 5             60          1.000        0.953
# 6             70          1.000        0.953
# 7             80          1.000        0.953
# 8             90          1.000        0.953
# 9            100          1.000        0.953
# 10           110          1.000        0.953
# 11           120          1.000        0.953
# 12           130          1.000        0.947
# 13           140          1.000        0.947
# 14           150          1.000        0.947

# %%
#모델 설명력 그래프 확인
plt.plot(para_n_tree, train_accuracy, linestyle = "-", label = 'Train Accuracy')
plt.plot(para_n_tree, val_accuracy, linestyle = "--", label = 'val Accuracy')
plt.xlabel('n_estimators')
plt.ylabel('accuracy')
plt.legend()

# %% [markdown]
# * train/val 데이터의 성능 변화를 고려하여 120 선택

# %% [markdown]
# ### n_estimators: 트리 수 변경에 따른 모델 oob error 모델

# %%
#error 저장 리스트
oob_error= []

for v_n_estimator in range(1,151):
    rf = RFC(n_estimators = v_n_estimator, oob_score = True, random_state = 1234)
    rf.fit(df_train_x, df_train_y)
    oob_error.append(1 - rf.oob_score_)
# Out:
# /home/piai/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:540: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/piai/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:544: RuntimeWarning: invalid value encountered in true_divide
#   decision = (predictions[k] /
# /home/piai/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:540: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/piai/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:544: RuntimeWarning: invalid value encountered in true_divide
#   decision = (predictions[k] /
# ...

# %%
#모델 설명력 그래프 확인
plt.plot(range(1,151), oob_error)
plt.ylabel('oob error')
plt.xlabel('n_estimators')
n_estimators = 120

# %% [markdown]
# * train/val 데이터의 성능 변화와 oob error 를 고려하여 120 선택

# %% [markdown]
# ### max_depth: 최대 깊이 변경에 따른 모델 성능

# %%
#max_depth: 최대 깊이 변경에 따른 모델 성능
#train 및 val 설명력 결과 저장
train_accuracy = []
val_accuracy = []

para_depth = [depth for depth in range(1,11)]

for v_max_depth in para_depth:
    tree = RFC(random_state = 1234,
                                  n_estimators = 120,
                                 max_depth = v_max_depth)
    tree.fit(df_train_x, df_train_y)
    train_accuracy.append(tree.score(df_train_x, df_train_y))
    val_accuracy.append(tree.score(df_val_x, df_val_y))

#결과 저장
df_accuracy_depth = pd.DataFrame()
df_accuracy_depth['Depth'] = para_depth
df_accuracy_depth['TrainScore'] = train_accuracy
df_accuracy_depth['valScore'] = val_accuracy
df_accuracy_depth.round(3)
# Out:
#    Depth  TrainScore  valScore
# 0      1       0.934     0.924
# 1      2       0.978     0.942
# 2      3       0.987     0.947
# 3      4       0.996     0.947
# 4      5       0.996     0.947
# 5      6       1.000     0.953
# 6      7       1.000     0.953
# 7      8       1.000     0.953
# 8      9       1.000     0.953
# 9     10       1.000     0.953

# %%
#모델 설명력 그래프 확인
plt.plot(para_depth, train_accuracy, linestyle = "-", label = 'Train Accuracy')
plt.plot(para_depth, val_accuracy, linestyle = "--", label = 'val Accuracy')
plt.xlabel('max depth')
plt.ylabel('accuracy')
plt.legend()

# %% [markdown]
# * 최대 깊이 증가에 따라 모델의 정확도는 증가하며 성능 변화를 고려하여 6 선택

# %% [markdown]
# ### min_samples_split : 분리 노드의 최소 자료 수 변경에 따른 모델 성능

# %%
#train 및 val 설명력 결과 저장
train_accuracy = []
val_accuracy = []

#min_samples_split : 분리노드 최소 자료 수 * 참조 : para_split : [1,2,3,...,19]

para_split = [n_split * 10 for n_split in range(1,11)]

for v_min_samples_split in para_split:
    tree = RFC(random_state = 1234,
                                n_estimators = 120,
                                 max_depth = 6,
                                 min_samples_split = v_min_samples_split)
    tree.fit(df_train_x, df_train_y)
    train_accuracy.append(tree.score(df_train_x, df_train_y))
    val_accuracy.append(tree.score(df_val_x, df_val_y))

#결과 저장
df_score_split = pd.DataFrame()
df_score_split['MinSamplesSplit'] = para_split
df_score_split['Trainaccuracy'] = train_accuracy
df_score_split['valaccuracy'] = val_accuracy
df_score_split.round(3)
# Out:
#    MinSamplesSplit  Trainaccuracy  valaccuracy
# 0               10          0.987        0.947
# 1               20          0.987        0.947
# 2               30          0.987        0.947
# 3               40          0.987        0.947
# 4               50          0.987        0.942
# 5               60          0.982        0.942
# 6               70          0.982        0.942
# 7               80          0.982        0.942
# 8               90          0.974        0.942
# 9              100          0.969        0.936

# %%
#모델 설명력 그래프 확인
plt.plot(para_split, train_accuracy, linestyle = "-", label = 'Train accuracy')
plt.plot(para_split, val_accuracy, linestyle = "--", label = 'val accuracy')
plt.xlabel('min sample split')
plt.ylabel('accuracy')
plt.legend()

# %% [markdown]
# * 분리 노드의 최소 자료 수 증가에 따라 모델의 정확도는 감소한다
# * 따라서 성능 변화를 고려하여 20 설정

# %% [markdown]
# ### min_samples_leaf : 잎사귀 노드의 최소 자료 수 변경에 따른 모델 성능

# %%
#train 및 val 설명력 결과 저장
train_accuracy = []
val_accuracy = []

#min_samples_leaf : 잎사귀 최소 자료 수 * 참조 : para_leaf : [1,2,3,...,19]

para_leaf = [n_leaf * 2 for n_leaf in range(1,11)]
for v_min_samples_leaf in para_leaf:
    tree = RFC(random_state = 1234 , n_estimators = 120, min_samples_split = 20,
                                  min_samples_leaf = v_min_samples_leaf,
                                  max_depth = 6)
    tree.fit(df_train_x, df_train_y)
    train_accuracy.append(tree.score(df_train_x, df_train_y))
    val_accuracy.append(tree.score(df_val_x, df_val_y))
    
#결과 저장
df_score_leaf = pd.DataFrame()
df_score_leaf['MinSamplesLeaf'] = para_leaf
df_score_leaf['TrainAccuracy'] = train_accuracy
df_score_leaf['valAccuracy'] = val_accuracy
#모델 설명력 확인
df_score_leaf.round(3)
# Out:
#    MinSamplesLeaf  TrainAccuracy  valAccuracy
# 0               2          0.987        0.947
# 1               4          0.987        0.947
# 2               6          0.987        0.947
# 3               8          0.982        0.947
# 4              10          0.982        0.947
# 5              12          0.978        0.947
# 6              14          0.974        0.947
# 7              16          0.969        0.942
# 8              18          0.960        0.947
# 9              20          0.960        0.947

# %%
#모델 설명력 그래프 확인
plt.plot(para_leaf, train_accuracy, linestyle = "-", label = 'Train accuracy')
plt.plot(para_leaf, val_accuracy, linestyle = "--", label = 'val accuracy')
plt.legend()

# %% [markdown]
# * 잎사귀 노드 최소 자료 수 증가에 따라 모델의 정확도는 감소한다
# * 성능 변화를 고려하여 최소 잎사귀 노드 수는 5로 설정

# %% [markdown]
# ### 최종 모델 선정

# %%
rf_final = RFC(random_state = 1234, 
             n_estimators = 120,
             min_samples_leaf = 5,
            min_samples_split = 20,
            max_depth = 6)
rf_final.fit(df_train_x, df_train_y)

#train 데이터 설명력
print('Score on training set : {:.3f}'.format(rf_final.score(df_train_x, df_train_y)))

#test 데이터 설명력
print('Score on test set : {:.3f}'.format(rf_final.score(df_test_x, df_test_y)))
# Out:
# Score on training set : 0.987
# Score on test set : 0.930

# %% [markdown]
# * 최종 모델 선정 결과 test 데이터의 설명력이 93.0% 인 것을 알 수 있다

# %%
y_pred = rf_final.predict(df_test_x)
print('Accuracy: {0:3f}\n'.format(rf_final.score(df_test_x, df_test_y)))
print('Confusion matrix : \n{}'.format(confusion_matrix(df_test_y, y_pred)))
# Out:
# Accuracy: 0.929825
#
# Confusion matrix :
# [[103   2]
#  [ 10  56]]

# %% [markdown]
# * confusion matrix 를 통해 확인해본 결과 이 모델은 안정적인 모델임을 확인할 수 있다

# %% [markdown]
# ### 결론 도출
# ### feature_importances_ : 설명변수의 중요도

# %%
#변수명 저장
v_feature_name = df_train_x.columns

#나무를 만들 때 사용되는 변수들의 중요도
#feature_importances_ : 설명변수의 중요도
#tree_final, feature_importances_로 설명변수 중요도 확인 및 테이블로 저장
df_importance = pd.DataFrame()
df_importance['Feature'] = v_feature_name
df_importance['Importance'] = rf_final.feature_importances_

#df_feature_importance 의 테이블을 중요도별로 정렬
df_importance.sort_values('Importance', ascending = False, inplace = True)
df_importance.round(3)
# Out:
#                     Feature  Importance
# 22          worst perimeter       0.138
# 27     worst concave points       0.134
# 20             worst radius       0.128
# 7       mean concave points       0.115
# 23               worst area       0.103
# 6            mean concavity       0.087
# 2            mean perimeter       0.065
# 0               mean radius       0.058
# 3                 mean area       0.036
# 13               area error       0.024
# 28           worst symmetry       0.023
# 26          worst concavity       0.023
# 12          perimeter error       0.010
# 5          mean compactness       0.009
# 25        worst compactness       0.009
# 24         worst smoothness       0.008
# 17     concave points error       0.006
# 21            worst texture       0.005
# 1              mean texture       0.005
# 29  worst fractal dimension       0.004
# 4           mean smoothness       0.002
# 8             mean symmetry       0.002
# ...

# %%
#설명변수 중요도 그래프, 중요도가 높은 변수를 상위에 그림
df_importance.sort_values('Importance', ascending = True, inplace = True)
coordinates = range(len(df_importance))
plt.barh(y = coordinates, width = df_importance['Importance'])
plt.yticks(coordinates, df_importance['Feature'])
plt.xlabel('설명변수 중요도')
plt.ylabel('설명변수')
# Out:
# Text(0, 0.5, '설명변수')

# %% [markdown]
# * 중요 설명 변수 : 트리 생성 시 worst perimeter, worst concave points , worst radius, mean concave points, worst area 순으로
# 유방암에 대한 영향도가 큰 것을 알 수 있음
# * 즉 유방암 악성을 구분하는데에 있어 worst perimeter, worst concave points , worst radius, mean concave points, worst area 변수가
# 큰 영향을 미치는 것을 알 수 있다.
